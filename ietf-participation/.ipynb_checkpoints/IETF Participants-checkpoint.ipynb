# %% [markdown]
# Our goal is to make a list of participants across IETF groups. Once we've done that, it should be possible to evaluate patterns of participation: how many people participate, in which groups, how does affiliation, gender, RFC authorship or other characteristics relate to levels of participation, and a variety of other related questions.
#
# Start by importing the necessary libraries.

# %%
# %matplotlib inline
import bigbang.mailman as mailman
import bigbang.graph as graph
import bigbang.process as process
from bigbang.parse import get_date
from bigbang.archive import Archive
import bigbang.utils as utils
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
import math
import pytz
import pickle
import os
import csv
import re
import scipy
import scipy.cluster.hierarchy as sch
import email

# %% [markdown]
# Let's start with a single IETF mailing list. (Later, we can expand to all current groups, or all IETF lists ever.)

# %%
list_url = 'https://www.ietf.org/mail-archive/text/perpass/' # perpass happens to be one that I subscribe to

ietf_archives_dir = '../../ietf-archives' # relative location of the ietf-archives directory/repo

list_archive = mailman.open_list_archives(list_url, ietf_archives_dir)
activity = Archive(list_archive).get_activity()
# Out:
# Opening 43 archive files

# %%
people = pd.DataFrame(activity.sum(0), columns=['perpass']) # sum the message count, rather than by date

# %%
people.describe()
# Out:
#           perpass
# count  261.000000
# mean     8.015326
# std     18.733961
# min      1.000000
# 25%      1.000000
# 50%      2.000000
# 75%      7.000000
# max    231.000000

# %% [markdown]
# Split out the email address and header name from the From header we started with.

# %%
# froms = pd.Series(people.index)
# emails = froms.apply(lambda x: email.utils.parseaddr(x)[1])
# emails.index = people.index
# names = froms.apply(lambda x: email.utils.parseaddr(x)[0])
# names.index = people.index
# people['email'] = emails
# people['name'] = names
# people

# %% [markdown]
# **Warning: long-running step.** Now repeat, parsing the archives and collecting the activities for all the mailing lists in the corpus.

# %%
f = open('ietf_lists_normalized.txt', 'r')
ietf_lists = f.readlines()

list_archives = []

for list_url in ietf_lists:
    try:
        archives = mailman.open_list_archives(list_url, ietf_archives_dir)
        list_archives.append((list_url, archives))
    except Exception as e:
        print str(e)
# Out:
# Opening 46 archive files
# x-unknown unknown encoding in message <Pine.GSO.4.64.0906040915000.16060@tin>, using UTF-8 instead
# x-unknown unknown encoding in message <Pine.GSO.4.64.0906101255320.9230@tin>, using UTF-8 instead
# Opening 54 archive files
# Opening 105 archive files
# windows-874 unknown encoding in message <BAY124-W4FAEF231B7F26B42380CCE44B0@phx.gbl>, using UTF-8 instead
# windows-874 unknown encoding in message <BAY124-W4FAEF231B7F26B42380CCE44B0@phx.gbl>, using UTF-8 instead
# x-windows-949 unknown encoding in message <43EA2A09.1070600@eng.sun.com>, using UTF-8 instead
# Opening 170 archive files
# cp 1252 unknown encoding in message <1513056.oYYGoBVvp1@linne>, using UTF-8 instead
# Opening 33 archive files
# Opening 58 archive files
# x-unknown unknown encoding in message <Pine.LNX.4.64.1506101537480.3552@ece.iisc.ernet.in>, using UTF-8 instead
# Opening 10 archive files
# Opening 79 archive files
# Opening 3 archive files
# Opening 47 archive files
# Opening 36 archive files
# Opening 19 archive files
# Opening 170 archive files
#  unknown encoding in message <1118910920.29417.34.camel@spot>, using UTF-8 instead
#  unknown encoding in message <1118910920.29417.34.camel@spot>, using UTF-8 instead
# Opening 144 archive files
# Date parsing error on:
# Thu, 30 Aug 2007 31:25:49 +0900
# Date parsing error on:
# Tue, 0 Jan 2008 15:40:34 +0100
# Date parsing error on:
# Tue, 0 Jan 2008 21:41:38 +0200
# Date parsing error on:
# Tue, 0 Jan 2008 20:30:32 -0600
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 10:14:21 +0800
# Date parsing error on:
# None
# Date parsing error on:
# Tue, 0 Jan 2008 03:57:37 +0900
# Date parsing error on:
# Tue, 0 Jan 2008 05:07:27 +0200
# Date parsing error on:
# Tue, 0 Jan 2008 05:42:12 +0100
# Date parsing error on:
# Sat, 15 Sep 2007 24:36:17 +0100
# windows-874 unknown encoding in message <000601c80169$b3d78920$5d06af3a@GUDDU>, using UTF-8 instead
# windows-874 unknown encoding in message <000601c80169$b3d78920$5d06af3a@GUDDU>, using UTF-8 instead
# "us-ascii"
#     content-transfer-encoding: 7bit unknown encoding in message <000001c70f43$5c5a5d80$0100007f@localhost>, using UTF-8 instead
# "us-ascii"
#     content-transfer-encoding: 7bit unknown encoding in message <000001c70f4f$c11bb500$0100007f@localhost>, using UTF-8 instead
# Date parsing error on:
# Sat, 1 Jul 2006 17:24:54 0000
# Date parsing error on:
# Mon, 31 Sep 2007 08:21:50 +0200
# Date parsing error on:
# Wed, 33 Sep 2007 04:26:45 +0200
# Date parsing error on:
# Thu, 34 Sep 2007 14:52:06 +0200
# Date parsing error on:
# Tue, 9 Oct 2007 25:49:38 +0200
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 21:09:53 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 20:51:05 +0100
# Date parsing error on:
# Fri, 32 Jan 2008 21:26:01 +0200
# Date parsing error on:
# Wed, 11 Nov 98 13:56:38 pst
# windows-874 unknown encoding in message <F7E4D46ABD8FD211928E00A0C9EBD1D603E0E810@ES01-SJC.bmc.com>, using UTF-8 instead
# Opening 107 archive files
# Opening 91 archive files
# Opening 41 archive files
# Opening 13 archive files
# Opening 56 archive files
# Opening 6 archive files
# Opening 8 archive files
# Opening 27 archive files
# x-unknown unknown encoding in message <201111142042.pAEKg1h21336@magenta.juniper.net>, using UTF-8 instead
# Opening 38 archive files
# Opening 67 archive files
# Opening 230 archive files
# Date parsing error on:
# Sun, 01 Oct 00 04:28:57 Eastern Daylight Time
# unknown-8bit unknown encoding in message <0FVU00DEWFCJ2U@mta5.rcsntx.swbell.net>, using UTF-8 instead
# Date parsing error on:
# Thu, 15 Jun 00 02:04:14 Ÿ�̺��� ǥ�ؽ�
# Date parsing error on:
# Sun, 05 Dec 99 09:25:02 Eastern Standard Time
# unknown-8bit unknown encoding in message <199912121943.DAA21571@sdnu.edu.cn>, using UTF-8 instead
# Date parsing error on:
# Mon, 23 Aug 99 19:25:23 PST8PDT
# unknown-8bit unknown encoding in message <10007130352.AA22702@pluto.anglia.ac.uk>, using UTF-8 instead
# Date parsing error on:
# Sat, 22 Jul 00 23:06:18 Eastern Daylight Time
# Date parsing error on:
# Sun, 30 Jul 00 23:24:12 Eastern Daylight Time
# Date parsing error on:
# Fri, 32 Jan 2008 10:51:03 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 05:59:34 +0300
# Date parsing error on:
# None
# Date parsing error on:
# Jan, 3 Dec 2006 13:36:28 -0600
# sv_se.8859-1 unknown encoding in message <Pine.GSO.4.21.0210101033440.22297-100000@chicken.stacken.kth.se>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3DBE35FB.70607@era.ericsson.se>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3DBEBD58.6090700@multicasttech.com>, using UTF-8 instead
# Date parsing error on:
# Wed, 12 Jan 00 02:13:37 Eastern Standard Time
# Date parsing error on:
# Tue, 25 Jan 00 02:01:09 Eastern Standard Time
# unknown-8bit unknown encoding in message <20090127200909.GA10484@isi.edu>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3D806EC5.7040902@era.ericsson.se>, using UTF-8 instead
# Date parsing error on:
# 27 Feb 00 12:14:00 +-0300
# unknown-8bit unknown encoding in message <200003040051.SAA07149@naucalpan>, using UTF-8 instead
# unknown-8bit unknown encoding in message <05e3a2518141030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <03e7e0837131030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <01b0d2208131030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Jan, 15 Oct 2006 23:07:33 +0300
# Date parsing error on:
# Fri, 32 Jan 2008 20:35:06 +0800
# Date parsing error on:
# Fri, 32 Jan 2008 15:48:00 +0200
# unknown-8bit unknown encoding in message <200004100555.OAA10919@dolphin.aralion.co.kr>, using UTF-8 instead
# Date parsing error on:
# Tue, 25 Apr 00 05:25:35 Ÿ�̺��� ǥ�ؽ�
# Date parsing error on:
# So, 30 Apr 2000 13:29:07
# Date parsing error on:
# Mon, 28 Aug 00 05:33:17 Eastern Daylight Time
# Date parsing error on:
# Thu, 31 Aug 100 07:15:40 +03d00
# unknown-8bit unknown encoding in message <200009030557.NAA01541@teda.com>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <91ECD6906EC7D211B27100204840464702F7469B@ismaildev.icomverse.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200009081236.FAA05950@snipe.prod.itd.earthlink.net>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <B65B4F8437968F488A01A940B21982BF21FC33@DYN-EXCH-001.dynamicsoft.com>, using UTF-8 instead
# Date parsing error on:
# Sun, 10 Sep 00 23:41:53 Eastern Daylight Time
# unknown-8bit unknown encoding in message <200009261808.DAA00933@www.daemyung.co.kr>, using UTF-8 instead
# unknown-8bit unknown encoding in message <199910040005.WAA01395@schumaker.hkj.gov.jo>, using UTF-8 instead
# _iso-2022-jp$esc unknown encoding in message <200407150952.FAA07345@ietf.org>, using UTF-8 instead
# windows-874 unknown encoding in message <000d01c72d96$523be5f0$e9ea1a7d@COM22>, using UTF-8 instead
# windows-874 unknown encoding in message <000d01c72d96$523be5f0$e9ea1a7d@COM22>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200005010415.MAA01831@hp.hz.zj.cn>, using UTF-8 instead
# Date parsing error on:
# Sun, 07 May 00 22:12:07 Eastern Daylight Time
# unknown-8bit unknown encoding in message <200005161244.MAA19310@hcgnet.com.br>, using UTF-8 instead
# Opening 230 archive files
# Date parsing error on:
# Sun, 01 Oct 00 04:28:57 Eastern Daylight Time
# unknown-8bit unknown encoding in message <0FVU00DEWFCJ2U@mta5.rcsntx.swbell.net>, using UTF-8 instead
# Date parsing error on:
# Thu, 15 Jun 00 02:04:14 Ÿ�̺��� ǥ�ؽ�
# Date parsing error on:
# Sun, 05 Dec 99 09:25:02 Eastern Standard Time
# unknown-8bit unknown encoding in message <199912121943.DAA21571@sdnu.edu.cn>, using UTF-8 instead
# Date parsing error on:
# Mon, 23 Aug 99 19:25:23 PST8PDT
# unknown-8bit unknown encoding in message <10007130352.AA22702@pluto.anglia.ac.uk>, using UTF-8 instead
# Date parsing error on:
# Sat, 22 Jul 00 23:06:18 Eastern Daylight Time
# Date parsing error on:
# Sun, 30 Jul 00 23:24:12 Eastern Daylight Time
# Date parsing error on:
# Fri, 32 Jan 2008 10:51:03 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 05:59:34 +0300
# Date parsing error on:
# None
# Date parsing error on:
# Jan, 3 Dec 2006 13:36:28 -0600
# sv_se.8859-1 unknown encoding in message <Pine.GSO.4.21.0210101033440.22297-100000@chicken.stacken.kth.se>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3DBE35FB.70607@era.ericsson.se>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3DBEBD58.6090700@multicasttech.com>, using UTF-8 instead
# Date parsing error on:
# Wed, 12 Jan 00 02:13:37 Eastern Standard Time
# Date parsing error on:
# Tue, 25 Jan 00 02:01:09 Eastern Standard Time
# unknown-8bit unknown encoding in message <20090127200909.GA10484@isi.edu>, using UTF-8 instead
# x-windows-949 unknown encoding in message <3D806EC5.7040902@era.ericsson.se>, using UTF-8 instead
# Date parsing error on:
# 27 Feb 00 12:14:00 +-0300
# unknown-8bit unknown encoding in message <200003040051.SAA07149@naucalpan>, using UTF-8 instead
# unknown-8bit unknown encoding in message <05e3a2518141030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <03e7e0837131030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <01b0d2208131030CHARTERALLIANCE@www.charteralliance.com>, using UTF-8 instead
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Jan, 15 Oct 2006 23:07:33 +0300
# Date parsing error on:
# Fri, 32 Jan 2008 20:35:06 +0800
# Date parsing error on:
# Fri, 32 Jan 2008 15:48:00 +0200
# unknown-8bit unknown encoding in message <200004100555.OAA10919@dolphin.aralion.co.kr>, using UTF-8 instead
# Date parsing error on:
# Tue, 25 Apr 00 05:25:35 Ÿ�̺��� ǥ�ؽ�
# Date parsing error on:
# So, 30 Apr 2000 13:29:07
# Date parsing error on:
# Mon, 28 Aug 00 05:33:17 Eastern Daylight Time
# Date parsing error on:
# Thu, 31 Aug 100 07:15:40 +03d00
# unknown-8bit unknown encoding in message <200009030557.NAA01541@teda.com>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <91ECD6906EC7D211B27100204840464702F7469B@ismaildev.icomverse.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200009081236.FAA05950@snipe.prod.itd.earthlink.net>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <B65B4F8437968F488A01A940B21982BF21FC33@DYN-EXCH-001.dynamicsoft.com>, using UTF-8 instead
# Date parsing error on:
# Sun, 10 Sep 00 23:41:53 Eastern Daylight Time
# unknown-8bit unknown encoding in message <200009261808.DAA00933@www.daemyung.co.kr>, using UTF-8 instead
# unknown-8bit unknown encoding in message <199910040005.WAA01395@schumaker.hkj.gov.jo>, using UTF-8 instead
# _iso-2022-jp$esc unknown encoding in message <200407150952.FAA07345@ietf.org>, using UTF-8 instead
# windows-874 unknown encoding in message <000d01c72d96$523be5f0$e9ea1a7d@COM22>, using UTF-8 instead
# windows-874 unknown encoding in message <000d01c72d96$523be5f0$e9ea1a7d@COM22>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200005010415.MAA01831@hp.hz.zj.cn>, using UTF-8 instead
# Date parsing error on:
# Sun, 07 May 00 22:12:07 Eastern Daylight Time
# unknown-8bit unknown encoding in message <200005161244.MAA19310@hcgnet.com.br>, using UTF-8 instead
# Opening 77 archive files
# Opening 26 archive files
# Opening 24 archive files
# Opening 114 archive files
# x-unknown unknown encoding in message <Pine.LNX.4.58.0709131428280.6691@tesla.psc.edu>, using UTF-8 instead
# Opening 37 archive files
# Opening 65 archive files
# Opening 165 archive files
# Opening 111 archive files
# unknown-8bit unknown encoding in message <0FVU00DSGFDJ39@mta5.rcsntx.swbell.net>, using UTF-8 instead
# unknown-8bit unknown encoding in message <77374D7B14D1.AAD2C0E@SINET2.sinet.net.cn>, using UTF-8 instead
# Opening 37 archive files
# Opening 71 archive files
# Opening 229 archive files
# iso-6887-9 unknown encoding in message <mailman.54.1092754249.3912.bmwg@ietf.org>, using UTF-8 instead
# windows-874 unknown encoding in message <e48401c77350$1824c7b0$0301a8c0@microsofa6d1e2>, using UTF-8 instead
# windows-874 unknown encoding in message <e48401c77350$1824c7b0$0301a8c0@microsofa6d1e2>, using UTF-8 instead
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 10:16:30 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 13:41:58 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 16:20:39 +0900
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Thu, 11 Oct 2007 24:46:39 +0900
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 18:49:40 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 21:27:20 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 12:49:37 -0500
# iso-2055-5 unknown encoding in message <mailman.251.1088794222.9512.bmwg@ietf.org>, using UTF-8 instead
# iso-9004-3 unknown encoding in message <mailman.49.1089625987.12931.bmwg@ietf.org>, using UTF-8 instead
# iso-7724-3 unknown encoding in message <mailman.99.1089813506.5280.bmwg@ietf.org>, using UTF-8 instead
# iso-3786-8 unknown encoding in message <mailman.140.1089996329.4601.bmwg@ietf.org>, using UTF-8 instead
# iso-2607-6 unknown encoding in message <mailman.13.1091006823.16634.bmwg@ietf.org>, using UTF-8 instead
# iso-7329-7 unknown encoding in message <mailman.7.1091268334.14625.bmwg@ietf.org>, using UTF-8 instead
# Opening 125 archive files
# unknown-8bit unknown encoding in message <0FVU00BDAFD5LQ@mta5.rcsntx.swbell.net>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200011020527.OAA11969@cmcc.co.jp>, using UTF-8 instead
# unknown-8bit unknown encoding in message <200011302016.EAA13093@mail.szbts.gov.cn>, using UTF-8 instead
# Opening 62 archive files
# Opening 148 archive files
# Opening 148 archive files
# Opening 28 archive files
# Opening 7 archive files
# Opening 19 archive files
# Opening 202 archive files
# Date parsing error on:
# ��, 28 ��� 2005 13:16:56 +0100
#  Return-path: <hensley@yahoo.com>
#  From: "Gysi"<hensley@yahoo.com>
#  To: <ccamp-archive@ietf.org>
#  Subject: Penis enlargement breakthrough!
#  Message-ID: <000801c5ab20$ac4dcc10$0700a8c0@wkuhddwi>
#  MIME-Version: 1.0
#  Content-Type: multipart/related;
#  	type="multipart/alternative";
#  	boundary="--=_NextPart_000_0004_01C5AB42.305894B0"
#  X-Priority: 3
#  X-MSMail-Priority: Normal
#  X-Mailer: Microsoft Outlook Express 6.00.2900.2180
#  X-MimeOLE: Produced By Microsoft MimeOLE V6.00.2900.2180
#
#  This is a multi-part message in MIME format.
#
#  ---=_NextPart_000_0004_01C5AB42.305894B0
#  Content-Type: multipart/alternative;
#  	boundary="--=_NextPart_001_0005_01C5AB42.305894B0"
#
#
#  ---=_NextPart_001_0005_01C5AB42.305894B0
#  Content-Type: text/html;
#  	charset="koi8-r"
#  Content-Transfer-Encoding: quoted-printable
#
#  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
#  <HTML><HEAD>
#  <META http-equiv=3DContent-Type content=3D"text/html; charset=3Dkoi8-r">
#  <META content=3D"MSHTML 6.00.2900.2180" name=3DGENERATOR>
#  <STYLE></STYLE>
#  </HEAD>
#  <BODY bgColor=3D#ffffff>
#  <DIV align=3Dleft><FONT face=3DArial size=3D2></FONT>&nbsp;</DIV>
#  <DIV align=3Dleft><FONT face=3DArial color=3D#ff0000 size=3D6><A=20
#  href=3D"http://www.meebwn.com/pt/?30&amp;jwewhjdw">Penis Enlargement =
#  Pills=20
#  !!!</A></FONT></DIV>
#  <DIV align=3Dleft><FONT face=3DArial size=3D2></FONT>&nbsp;</DIV>
#  <DIV align=3Dleft><A =
#  href=3D"http://www.meebwn.com/pt/?30&amp;jwewhjdw"><IMG alt=3D""=20
#  hspace=3D0 src=3D"cid:000301c5ab20$a94483b0$0700a8c0@sanya" =
#  align=3Dbaseline=20
#  border=3D0></A></DIV>
#  <DIV align=3Dleft><FONT face=3DArial size=3D2></FONT>&nbsp;</DIV>
#  <DIV align=3Dleft><A =
#  href=3D"http://www.meebwn.com/pt/?30&amp;jwewhjdw">Hey man,=20
#  check out the discounts these guys are offering on enlarge =
#  patches!<BR><BR>Steel=20
#  Package: 10 Patches reg $79.95 <B>Now $49.95</B> ! Free shipping=20
#  too!<BR><BR>Silver Package: 25 Patches reg $129.95, <B>Now $99.95!</B> =
#  Free=20
#  shipping and free exercise manual included!<BR><BR>Gold Package: 40 =
#  Patches reg=20
#  $189.95, <B>Now $149.95!</B> Free shipping and free exercise manual=20
#  included!<BR><BR>Platinum Package: 65 Patches reg $259.95, <B>Now =
#  $199.95!</B>=20
#  Free shipping and free exercise manual included!<BR><BR>Millions of men =
#  are=20
#  taking advantage of this revolutionary new product - <B>Don't be left=20
#  behind!</B> </A></DIV>
#  <DIV align=3Dleft><FONT face=3DArial =
#  size=3D2></FONT>&nbsp;</DIV></BODY></HTML>
#
#  ---=_NextPart_001_0005_01C5AB42.305894B0-
#
#  ---=_NextPart_000_0004_01C5AB42.305894B0
#  Content-Type: image/jpeg;
#  	name="penis.jpg"
#  Content-Transfer-Encoding: base64
#  Content-ID: <000301c5ab20$a94483b0$0700a8c0@sanya>
#
#  /9j/4AAQSkZJRgABAgAAZABkAAD/7AARRHVja3kAAQAEAAAAHgAA/+4AIUFkb2JlAGTAAAAAAQMA
#  EAMCAwYAAAqoAAAYbgAAQxf/2wCEABALCwsMCxAMDBAXDw0PFxsUEBAUGx8XFxcXFx8eFxoaGhoX
#  Hh4jJSclIx4vLzMzLy9AQEBAQEBAQEBAQEBAQEABEQ8PERMRFRISFRQRFBEUGhQWFhQaJhoaHBoa
#  JjAjHh4eHiMwKy4nJycuKzU1MDA1NUBAP0BAQEBAQEBAQEBAQP/CABEIAOkBdgMBIgACEQEDEQH/
#  xADcAAACAwEBAQAAAAAAAAAAAAAABAEDBQIGBwEBAAMBAQAAAAAAAAAAAAAAAAECAwQFEAACAgIC
#  AQIGAgICAwEAAAABAgMEAAUREgYhExAgMDEUFUEyIhZCI0AzJDQRAAIBAgQEAwMGCQcLAgcAAAEC
#  AwARITESBEFRIhNhcTKBkRQQodFCIzQgMLHBUjOT0wVicoKS0iSU8OGissJDU2Nzw+NAg/GzRGR0
#  FTUSAAIBAwEHAwMDAwUAAAAAAAABESExAkEQMFFhcYGRobES4SIy8MFSIGLSQNHxQnL/2gAMAwEA
#  AhEDEQAAAPoAAABEwC7CNLTVFfJt21lv9ON0xOkExMSBBMATAERPInXcjEKr2cY6oXVt8/QxsZUd
#  fHs098YbMkcIcvoU68dQwbLRtGOGwee0TQMTo2THDYAAAImAQfSyvUk0rwdPParXTnp9Zej1c9sR
#  MWJ5ETAAHEulrKqzVTbUjNrYqpNK+itW69rfFLss43pZqoXWZWOXGu3Dy2htloyKd0MB3SDENsMg
#  1wmJgoMzJPUHlqT2lPn9OJ7qVjzOmllNCN93muezi0GfPxtTe4wqKX26MevPTThO3LVthCZrqU5r
#  XRhCTkaYJTXbz9XnrOGOffZ9F57YvnaVWxFryL3Vl1MTtmAAAAAAAQAUWHZVaFF9MSsu/n8G8JP8
#  8e3Vs8+jz03dcWjNynqeXqy+bKLRZzRKOmqe4nT7yNeLWdrsd/nK1FuWyBQ3z9TWt5zYnPUuybZz
#  b1PM2b19JPmuejL055HbNMiQAAA89m+yDxOn6MPHR7IPH7OvTE5im6jz6Ixo8+dqp21V1UuytTF3
#  aKO0hS2Yg6cvVnF3Sc01a5qm3X1arHNLN6Us8V3oo+k1S920mwrbdHXGztnB1u6rPak93Nffn8mr
#  JBHIY5ZUd0YQZSdRxOktbTq0enVbjSJJBqWMaVGph0lteg2OIByHClkEA1o0jqccGmwkOfGk28K6
#  IoxZFxwHt/EEIoUEkkAWxOJNZfIryxK7R4ozAEqfCj5/IrHMXtQBztx/NQvwq/yFJVVxxB/NQbbN
#  p42Yn5jV/ibNyxwFCWS80ox1ucL87UAAABwGFYVz/A8q/P8AJ5/JblWFc6/N+CPL/wBCfP5PfSeV
#  D5RTeVeyvZ+GflHyH8QPL8V//9k=
#
#  ---=_NextPart_000_0004_01C5AB42.305894B0-
# None unknown encoding in message <13108213495d.13495d131082@huawei.com>, using UTF-8 instead
# Date parsing error on:
# %M5DATE
# Date parsing error on:
# %M5DATE
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# lun, 21 ene 2008 17:26:05 -0300
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 04:05:33 +0200
# Date parsing error on:
# Fri, 32 Jan 2008 14:44:29 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 07:09:20 +0000
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# iso-8859-8-i unknown encoding in message <000b01c72a76$396c39d0$c9fb84d9@5vd1f19hlmi8edx>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <000b01c72a76$396c39d0$c9fb84d9@5vd1f19hlmi8edx>, using UTF-8 instead
# Date parsing error on:
# Di, 22 Mai 2007 19:45:45 +0200
# Date parsing error on:
# Sat, 32 Aug 2007 23:16:33 +0900
# Date parsing error on:
# Mon, 34 Aug 2007 12:26:37 +0900
# Date parsing error on:
# Mon, 34 Aug 2007 28:35:29 +0900
# Date parsing error on:
# Tue, 35 Aug 2007 15:05:54 +0900
# Date parsing error on:
# Tue, 35 Aug 2007 30:18:10 +0900
# Date parsing error on:
# Wed, 36 Aug 2007 18:48:34 -0500
# Date parsing error on:
# Thu, 13 Sep 2007 25:03:10 +0200
# Date parsing error on:
# Thu, 29 Jan   Paris, Madrid
# "us-ascii"
#     content-transfer-encoding: 7bit unknown encoding in message <000001c7097e$d6f10f00$0100007f@localhost>, using UTF-8 instead
# "us-ascii"
#     content-transfer-encoding: 7bit unknown encoding in message <000001c7097e$d6f10f00$0100007f@localhost>, using UTF-8 instead
# Date parsing error on:
# None
# Date parsing error on:
# Per, 07 Haz 2007 15:39:50 +0300
# Date parsing error on:
# Mon, 31 Sep 2007 21:55:18 +0900
# Date parsing error on:
# Wed, 33 Sep 2007 -02:33:02 -0300
# Date parsing error on:
# None
# Date parsing error on:
# %M5DATE
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# None
# Date parsing error on:
# Sat, 24 Jun 2006 14:22:37 -0-100
# Date parsing error on:
# Fri, 32 Jan 2008 11:09:24 +0200
# Date parsing error on:
# Fri, 32 Jan 2008 11:58:31 +0100
# Date parsing error on:
# lun, 04 jul 2005 23:43:33 +0100
# Date parsing error on:
# ��, 06 7 2005 15:22:10 +0100
# Date parsing error on:
# �ar, 06 Tem 2005 09:27:35 +0100
# Date parsing error on:
# Wed, 06 Jul 2005 18:49:20 +0400 EST
# x-unknown unknown encoding in message <20050728085618.M12097@zircon.juniper.net>, using UTF-8 instead
# x-unknown unknown encoding in message <20050728103500.V12097@zircon.juniper.net>, using UTF-8 instead
# x-unknown unknown encoding in message <20041122073615.O16843@kummer.juniper.net>, using UTF-8 instead
# Date parsing error on:
# Di, 01 Nov 2005 01:05:34 +0100
# Opening 81 archive files
# Opening 25 archive files
# Opening 179 archive files
# x-unknown unknown encoding in message <Pine.GSO.4.63.0603221704370.21526@irp-view7.cisco.com>, using UTF-8 instead
# x-unknown unknown encoding in message <Pine.GSO.4.63.0603231127160.18621@helios.isrc.qut.edu.au>, using UTF-8 instead
# iso-2077-9 unknown encoding in message <200408080749.DAA05808@ietf.org>, using UTF-8 instead
# iso-2793-9 unknown encoding in message <200408101331.JAA25589@ietf.org>, using UTF-8 instead
# iso-1199-4 unknown encoding in message <3175833172100856583.60749.DHPZYZAKYFCN@didamail.com>, using UTF-8 instead
# iso-8755-8 unknown encoding in message <3797757000.09723@rkhvusi@myway.com>, using UTF-8 instead
# iso-6435-6 unknown encoding in message <6977219769391.40121@crrrpzsipvkzf@whale-mail.com>, using UTF-8 instead
# unknown-8bit unknown encoding in message <20130812193458.GF14392@zooko.com>, using UTF-8 instead
# x-unknown unknown encoding in message <Pine.GSO.4.21.0212140623530.8925-100000@ee.technion.ac.il>, using UTF-8 instead
# Date parsing error on:
# Wed, 09 Jun 2004 22:29:19 -0500 EST
# iso-7948-9 unknown encoding in message <5225362232117.56679@qgxshbkxmvlsu@aaiworldmarket.com>, using UTF-8 instead
# iso-1557-7 unknown encoding in message <9503307789.39464@orredbtlkg@aaiworldmarket.com>, using UTF-8 instead
# iso-5802-3 unknown encoding in message <706358958116.24281@iaekr@aaiworldmarket.com>, using UTF-8 instead
# iso-6445-4 unknown encoding in message <975310131437.73758@ubercuqcqts@aaiworldmarket.com>, using UTF-8 instead
# iso-1877-4 unknown encoding in message <035675621.15254@OUAYO@aaiworldmarket.com>, using UTF-8 instead
# iso-0974-8 unknown encoding in message <4020591908232.68864@kbkmjzjmv@catchamail.com>, using UTF-8 instead
# iso-3428-4 unknown encoding in message <196934009582.38781@Margie@compuserve.com>, using UTF-8 instead
# iso-9875-2 unknown encoding in message <461362287258.32113@Lakisha@lopezclub.com>, using UTF-8 instead
# iso-6616-2 unknown encoding in message <357754733440614000.84630207.pszgbmr@list.ru>, using UTF-8 instead
# iso-3186-4 unknown encoding in message <0324856888.10858@welgqpfoiic@macmail.com>, using UTF-8 instead
# Opening 17 archive files
# Opening 85 archive files
# macintosh unknown encoding in message <CAHBDyN6O1gvyOagH=QK1TjtRVgR0cavfppqw62yrFMR_Sgxo_g@mail.gmail.com>, using UTF-8 instead
# Opening 0 archive files
# 'No messages in ../../ietf-archives under ietf-quality. Did you run the collect_mail.py script?'
# Opening 88 archive files
# Opening 61 archive files
# Opening 93 archive files
# Opening 31 archive files
# Opening 91 archive files
# Opening 53 archive files
# cp 850 unknown encoding in message <200805281745.43351.elevyabe@cisco.com>, using UTF-8 instead
# Opening 24 archive files
# Opening 49 archive files
# Opening 83 archive files
# unknown-8bit unknown encoding in message <20130730152332.GA2603@mournblade.imrryr.org>, using UTF-8 instead
# Opening 9 archive files
# Opening 46 archive files
# Opening 32 archive files
# Opening 120 archive files
# Opening 7 archive files
# Opening 39 archive files
# Opening 37 archive files
# Opening 39 archive files
# Opening 231 archive files
# Date parsing error on:
# Thu, 22 Mar 2007 11:31:06 +0From dhcwg-bounces@ietf.org Tue Mar 27 09:31:47 2007
# Date parsing error on:
# Fri, 32 Jan 2008 17:21:29 +0900
# x-unknown unknown encoding in message <Pine.GSO.4.44.0206100612370.1042-100000@funnel.cisco.com>, using UTF-8 instead
# Date parsing error on:
# Thu, 2 Mar 100 16:59:14 -800
# Opening 37 archive files
# Opening 141 archive files
# Opening 146 archive files
# Date parsing error on:
# 2/4/99 17:58:23 PM Eastern StandardTime
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 07:05:50 +0200
# Date parsing error on:
# Fri, 32 Jan 2008 00:52:29 -0700
# Date parsing error on:
# Fri, 32 Jan 2008 17:28:25 +0900
# Date parsing error on:
# Fri, 32 Jan 2008 17:28:31 +0900
# x-unknown unknown encoding in message <Pine.GSO.4.21.0101040958100.8866-100000@rtp-cse-133.cisco.com>, using UTF-8 instead
# Date parsing error on:
# None
# Date parsing error on:
# Fri, 32 Jan 2008 12:06:07 +0300
# Date parsing error on:
# Fri, 32 Jan 2008 13:40:03 +0300
# Date parsing error on:
# Fri, 32 Jan 2008 12:59:34 +0200
# Date parsing error on:
# Fri, 32 Jan 2008 17:43:44 +0000
# Date parsing error on:
# Thu,  5 Nov 98 10:28:23 pst
# x-roman8 unknown encoding in message <200108081256.NAA20952@swale.hpfarm.csc.liv.ac.uk>, using UTF-8 instead
# Opening 103 archive files
# Opening 0 archive files
# 'No messages in ../../ietf-archives under ietf-dkim. Did you run the collect_mail.py script?'
# Opening 56 archive files
# Opening 80 archive files
# Opening 11 archive files
# Opening 188 archive files
# Date parsing error on:
# Sal, 06 �ub 2007 12:57:38 +0200
# Date parsing error on:
# ������, 15 ������ 2007 01:05:59 +0200
# Date parsing error on:
# ter, 13 set 2005 15:41:06 +0100
# Date parsing error on:
# �, 11 8 2005 09:46:32 +0100
# Date parsing error on:
# ...
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503071042.FAA25539@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1D8h8F-0001Oj-Qc@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503091010.FAA10315@ietf.org>, using UTF-8 instead
# iso-6182-2 unknown encoding in message <E1DAOfb-0007OQ-0I@mx2.foretec.com>, using UTF-8 instead
# iso-2587-9 unknown encoding in message <200503170107.UAA20692@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503170900.EAA26535@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503171225.HAA17652@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1DBu17-0004sj-3q@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503180237.VAA16950@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200503181950.OAA16879@ietf.org>, using UTF-8 instead
# iso-1478-3 unknown encoding in message <200503221416.JAA16087@ietf.org>, using UTF-8 instead
# iso-6250-4 unknown encoding in message <6264752657571.39688@caracy>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1DFsWZ-0001Qh-Ht@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1DFsZI-0001U1-GG@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502010544.AAA27319@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1Cw1u3-0001A4-1C@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502011807.NAA01688@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502020656.BAA06636@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502020704.CAA11989@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CwcAe-00085L-S1@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CwixB-0002Lt-CC@mx2.foretec.com>, using UTF-8 instead
# iso-7797-5 unknown encoding in message <7F3AA5E99FB4.190E5@2.asthma@chemie.tu-dresden.de>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502052311.SAA09533@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CyJQL-0007u2-R9@mx2.foretec.com>, using UTF-8 instead
# iso-9369-4 unknown encoding in message <893BDDA66A.9164D@synthesisDYPYGDMFLLCP@alice.dp.ua>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502100638.BAA07829@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CzTna-00006F-IT@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502121607.LAA11992@ietf.org>, using UTF-8 instead
# iso-3b85-e unknown encoding in message <200502140732.CAA29012@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502141617.LAA18369@ietf.org>, using UTF-8 instead
# iso-0bc8-9 unknown encoding in message <200502141806.NAA28438@ietf.org>, using UTF-8 instead
# iso-5204-8 unknown encoding in message <178494930.06490@tamara>, using UTF-8 instead
# iso-aea0-2 unknown encoding in message <E1D2sIs-00069b-F5@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502211313.IAA23199@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502211319.IAA23925@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502220406.XAA00611@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502220438.XAA04632@ietf.org>, using UTF-8 instead
# iso-4960-6 unknown encoding in message <8265335913718.67582@ezntmyenlt@yahoo.com>, using UTF-8 instead
# default unknown encoding in message <E1D3kna-0000HJ-59@mx2.foretec.com>, using UTF-8 instead
# default unknown encoding in message <200502230231.VAA27371@ietf.org>, using UTF-8 instead
# default unknown encoding in message <200502232204.RAA25211@ietf.org>, using UTF-8 instead
# default unknown encoding in message <200502240057.TAA02684@ietf.org>, using UTF-8 instead
# default unknown encoding in message <E1D48Z6-0000xh-Fb@mx2.foretec.com>, using UTF-8 instead
# iso-4453-3 unknown encoding in message <799D3A8937.54ACD@cfszkvuscmfSheena@na.rim.or.jp>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502271154.GAA18607@ietf.org>, using UTF-8 instead
# Date parsing error on:
# Sat, 28 Feb   ���������� �����
# iso-8740xub0625-235spyfrm unknown encoding in message <200501022125.QAA05733@ietf.org>, using UTF-8 instead
# iso-7653ikx1615-452vxobyp unknown encoding in message <E1Clcz7-000861-K5@mx2.foretec.com>, using UTF-8 instead
# iso-8308lik8744-523dvaxwd unknown encoding in message <200501050635.BAA01247@ietf.org>, using UTF-8 instead
# iso-0122ciy0395-286sqzpwz unknown encoding in message <200501050722.CAA24727@ietf.org>, using UTF-8 instead
# iso-9740hhw4348-026vyxzrp unknown encoding in message <E1CmIoE-0003sF-QP@mx2.foretec.com>, using UTF-8 instead
# iso-3923myd6699-105mwfjll unknown encoding in message <E1Cmf5O-0003uo-0y@mx2.foretec.com>, using UTF-8 instead
# iso-5064pjn1992-737kubtcm unknown encoding in message <E1Cmgrz-0008F7-HN@mx2.foretec.com>, using UTF-8 instead
# iso-9514qzn7987-373ypdylu unknown encoding in message <200501072105.QAA27161@ietf.org>, using UTF-8 instead
# iso-3590ehc4045-628sqwwyv unknown encoding in message <200501092133.QAA08696@ietf.org>, using UTF-8 instead
# iso-8066aaw6382-899nszyvf unknown encoding in message <200501122241.RAA24224@ietf.org>, using UTF-8 instead
# iso-6310lxf7218-369rhyeau unknown encoding in message <200501140016.TAA08805@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501180028.TAA09092@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501180045.TAA10042@ietf.org>, using UTF-8 instead
# Date parsing error on:
# Tue, 18 Jan 2005 08:15:05 -0600 EST
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CrM70-0005wb-5t@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501192032.PAA19388@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CrgDS-0001oG-TF@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501240724.CAA12664@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501240737.CAA13925@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501250403.XAA07907@ietf.org>, using UTF-8 instead
# iso-fdde-b unknown encoding in message <271A6B26872DC5ED.40D0A@iiehwp@interlink.or.jp>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CthCj-0002QT-Uo@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501270504.AAA01881@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1Cu44C-0008Om-6u@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1Cu4Kr-0000O8-DI@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501280537.AAA08965@ietf.org>, using UTF-8 instead
# iso-4897-2 unknown encoding in message <5292692208451821040.18932@gmquewtretasdd@cadwell.com>, using UTF-8 instead
# iso-42c8-4 unknown encoding in message <20A5DAE09DE.7686A@lgi.lg.co.kr>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CvBX1-0008IA-UV@mx2.foretec.com>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200501310408.XAA29635@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <200502010408.XAA16854@ietf.org>, using UTF-8 instead
# iso-%digits%lcvalues%digits%digits%lcvalues unknown encoding in message <E1CvpR3-0003aY-RH@mx2.foretec.com>, using UTF-8 instead
# iso-4983-7 unknown encoding in message <E1CEKja-0002W5-Bb@mx2.foretec.com>, using UTF-8 instead
# iso-5789-5 unknown encoding in message <E1CEVR5-0001CL-3F@mx2.foretec.com>, using UTF-8 instead
# iso-9384-7 unknown encoding in message <E1CFQqn-0003rO-Qe@mx2.foretec.com>, using UTF-8 instead
# %charset unknown encoding in message <jgvortqenc@mossbridge.com>, using UTF-8 instead
# %charset unknown encoding in message <jgvortqenc@mossbridge.com>, using UTF-8 instead
# iso-9194-1 unknown encoding in message <2714093.3560.VCElvv.0569f@onlyforjesus.com>, using UTF-8 instead
# iso-4287-0 unknown encoding in message <200410140452.AAA18437@ietf.org>, using UTF-8 instead
# iso-2094-7 unknown encoding in message <E1CI4zt-0000j3-2T@mx2.foretec.com>, using UTF-8 instead
# iso-3746-1 unknown encoding in message <673184546473.91980@VDKOX@yahoo.com>, using UTF-8 instead
# iso-5740-3 unknown encoding in message <305795$56253ROQ$02@satx.rr.com>, using UTF-8 instead
# iso-9928-3 unknown encoding in message <845683.7267226.Rsbwk.8065r@inficad.com>, using UTF-8 instead
# iso-8ae1-7 unknown encoding in message <B28F04B4355.38892@24.126.212.29>, using UTF-8 instead
# iso-3db6-9 unknown encoding in message <A72E16B452BD3A.86A81@fmmjusqjjkade@ecua.net.ec>, using UTF-8 instead
# iso-9677-3 unknown encoding in message <kdiasqizvqebmoflwolcf@127.0.0.1>, using UTF-8 instead
# unknown-8bit unknown encoding in message <199803031919.OAA22917@access2.digex.net>, using UTF-8 instead
# iso-2223-9 unknown encoding in message <cotzbpriffogioojepg@127.0.0.1>, using UTF-8 instead
# iso-6364-9 unknown encoding in message <fwrmguzmqhhupqpigf@127.0.0.1>, using UTF-8 instead
# iso-6c01-8 unknown encoding in message <1Bty$6C52rfrkoq@thdez34B71.beecham.WANGYMA@oasanet.cz>, using UTF-8 instead
# iso-2478-8 unknown encoding in message <E1Blzy9-0004Wl-Rl@mx2.foretec.com>, using UTF-8 instead
# iso-c7e7-7 unknown encoding in message <41x$FBDjhkdlzo@xyyos881.soot.YFZUGCFEOV@tlyeo.com>, using UTF-8 instead
# iso-7bda-e unknown encoding in message <57C33FBFECA.0CDD8@zvnflrdleddzk@gmd.de>, using UTF-8 instead
# iso-1377-8 unknown encoding in message <93023$365843LGFQ$59010@freeuk.com>, using UTF-8 instead
# iso-9552-7 unknown encoding in message <E1Bo4EH-0003oB-6Q@mx2.foretec.com>, using UTF-8 instead
# iso-5710-0 unknown encoding in message <E1Bpv5A-00065p-HT@mx2.foretec.com>, using UTF-8 instead
# iso-2916-2 unknown encoding in message <649700$1843FSAT$7775@nc.rr.com>, using UTF-8 instead
# iso-a390-c unknown encoding in message <60E549CB769.7824D@nbghbcshi@mi.terra.cl>, using UTF-8 instead
# iso-2640-5 unknown encoding in message <E1CP6BZ-0007KT-Be@mx2.foretec.com>, using UTF-8 instead
# iso-0204-6 unknown encoding in message <999146797697613.14307@DACYKXV@hotmail.com>, using UTF-8 instead
# iso-9448-4 unknown encoding in message <200411081859.NAA13570@ietf.org>, using UTF-8 instead
# iso-4623-9 unknown encoding in message <GWCBYXQVJCNHCWRT@127.0.0.1> , using UTF-8 instead
# iso-2496-7 unknown encoding in message <HENNJPUEPOMVQNKYLJ@80.207.88.212> , using UTF-8 instead
# iso-9165-4 unknown encoding in message <QIKTJXOIUCHVLEUXMFF@127.0.0.1> , using UTF-8 instead
# %charset unknown encoding in message <588360@hemimetabole>, using UTF-8 instead
# %charset unknown encoding in message <588360@hemimetabole>, using UTF-8 instead
# %charset unknown encoding in message <wizuppcfww@decisionhaus.com>, using UTF-8 instead
# %charset unknown encoding in message <wizuppcfww@decisionhaus.com>, using UTF-8 instead
# %charset unknown encoding in message <wqjwypsqfs@no-hiccups.com>, using UTF-8 instead
# %charset unknown encoding in message <wqjwypsqfs@no-hiccups.com>, using UTF-8 instead
# Opening 47 archive files
# Opening 182 archive files
# cp 1252 unknown encoding in message <6788197.iuYbI3p2ZC@linne>, using UTF-8 instead
# cp 1252 unknown encoding in message <6788197.iuYbI3p2ZC@linne>, using UTF-8 instead
# Date parsing error on:
# Tue, 0 Jan 2008 18:00:02 +0100
# Date parsing error on:
# Tue, 0 Jan 2008 22:32:37 -0400
# Date parsing error on:
# jeu., 28 f�vr. 2002 01:25:06 +0100
# Date parsing error on:
# Pzt, 02 Nis 2007 13:34:25 +0300
# Date parsing error on:
# ��������, 18 ����� 2007 14:13:54 +0300
# unknown-8bit unknown encoding in message <20170403094743.GA14217@ernw.de>, using UTF-8 instead
# x-unknown unknown encoding in message <Pine.GSO.4.44.0211071429170.5382-100000@satapati-u10.cisco.com>, using UTF-8 instead
# Date parsing error on:
# None
# iso-8859-8-i unknown encoding in message <000601c7f671$77be8360$267f6e54@gigabytea19608>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <000601c7f671$77be8360$267f6e54@gigabytea19608>, using UTF-8 instead
# Date parsing error on:
# Fr, 08 Jun 2007 13:35:51 +0200
# Date parsing error on:
# Thu, 4 Oct 2007 24:00:33 +0900
# iso-8859-8-i unknown encoding in message <000b01c807b7$7116d330$41976e54@roni>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <000b01c807b7$7116d330$41976e54@roni>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <000d01c80cda$b2efe850$0925fa55@omri139e779b1b>, using UTF-8 instead
# iso-8859-8-i unknown encoding in message <000d01c80cda$b2efe850$0925fa55@omri139e779b1b>, using UTF-8 instead
# x-unknown unknown encoding in message <Pine.LNX.4.53.0309151222200.18225@giskard.ing.unife.it>, using UTF-8 instead
# Date parsing error on:
# Fri, 06 Mar   Pacific Standard Time
# Date parsing error on:
# Fri, 32 Jan 2008 13:08:29 +0100
# Date parsing error on:
# Fri, 32 Jan 2008 18:09:04 +0200
# Date parsing error on:
# Fri, 32 Jan 2008 12:33:14 -0500
# Date parsing error on:
# lun, 08 nov 2004 21:52:27 -0300
# Opening 89 archive files
# Opening 45 archive files
# Opening 17 archive files
# Opening 14 archive files
# Opening 56 archive files
# Opening 168 archive files
# unknown-8bit unknown encoding in message <0FVU00DK6FDP2U@mta5.rcsntx.swbell.net>, using UTF-8 instead
# unknown-8bit unknown encoding in message <20001130201815.SM00453@mainserver.ps.gov.cn>, using UTF-8 instead
# Date parsing error on:
# Tue, 0 Jan 2008 18:00:02 +0100
# Date parsing error on:
# Tue, 0 Jan 2008 22:32:37 -0400
# windows-874 unknown encoding in message <000d01c839e3$fbbfa760$e6822f75@home8ec9fe66a5>, using UTF-8 instead
# windows-874 unknown encoding in message <000d01c839e3$fbbfa760$e6822f75@home8ec9fe66a5>, using UTF-8 instead
# Date parsing error on:
# Tue, 31 Nov 2006 18:08:46 -0060
# Date parsing error on:
# Mon, 04 Sep 00 06:31:30 Pacific Daylight Time
# Date parsing error on:
# Thu, 25 Nov 04 14:45:09 �x�_�зǮɶ�
# Opening 13 archive files
# Opening 75 archive files
# Opening 0 archive files
# 'No messages in ../../ietf-archives under webi-archive. Did you run the collect_mail.py script?'
# Opening 38 archive files
# Opening 64 archive files
# Opening 55 archive files
# Opening 43 archive files
# Opening 8 archive files
# Opening 26 archive files
# Opening 11 archive files
# Opening 103 archive files
# Opening 47 archive files
# Opening 126 archive files
# Opening 0 archive files
# 'No messages in ../../ietf-archives under xmppwg. Did you run the collect_mail.py script?'
# Opening 76 archive files
# Opening 29 archive files

# %%
len(list_archives)
# Out:
# 341

# %%
reload(bigbang.archive)
# Out:
# <module 'bigbang.archive' from '/Users/nick/code/mailing-list-analysis/bigbang/bigbang/archive.py'>

# %%
activity_frames = []
for (list_url, list_archive) in list_archives:
    activity = bigbang.archive.Archive(list_archive).get_activity()
    list_name = mailman.get_list_name(list_url)
    activity_frame = pd.DataFrame(activity.sum(0), columns=[list_name])
    activity_frames.append(activity_frame)
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-55-ef83e88dcc89> in <module>()
#       1 activity_frames = []
#       2 for (list_url, list_archive) in list_archives:
# ----> 3     activity = Archive(list_archive).get_activity()
#       4     list_name = mailman.get_list_name(list_url)
#       5     activity_frame = pd.DataFrame(activity.sum(0), columns=[list_name])
#
# /Users/nick/code/mailing-list-analysis/bigbang/bigbang/archive.py in __init__(self, data, archive_dir, mbox)
#      53             self.data = mailman.load_data(data,archive_dir=archive_dir,mbox=mbox)
#      54
# ---> 55         self.data['Date'] = pd.to_datetime(self.data['Date'], errors='coerce', infer_datetime_format=True, utc=True)
#      56         self.data.drop_duplicates(inplace=True)
#      57
#
# /usr/local/lib/python2.7/site-packages/pandas/util/decorators.pyc in wrapper(*args, **kwargs)
#
# /usr/local/lib/python2.7/site-packages/pandas/tseries/tools.pyc in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#
# /usr/local/lib/python2.7/site-packages/pandas/tseries/tools.pyc in _to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, freq, infer_datetime_format)
#
# /usr/local/lib/python2.7/site-packages/pandas/tseries/tools.pyc in _convert_listlike(arg, box, format, name)
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1601-01-01 00:39:27

# %%
pd.merge(people, acme, how='outer', left_index=True, right_index=True)
# Out:
#                                                     perpass  \
# From
# "Adrian Farrel" <adrian@olddog.co.uk>                   3.0
# "Andreas Kuckartz" <a.kuckartz@ping.de>                 8.0
# "Andy Ligg" <andy@startssl.com>                         NaN
# "Bernie Volz (volz)" <volz@cisco.com>                   1.0
# "Carl S. Gutekunst" <cgutekunst@sonicwall.com>          3.0
# "Christian Huitema " <huitema@huitema.net>              1.0
# "Christian Huitema" <huitema@huitema.net>              39.0
# "Cullen Jennings (fluffy)" <fluffy@cisco.com>           3.0
# "Dickson, Brian" <bdickson@verisign.com>                1.0
# "Dr. Pala" <director@openca.org>                        NaN
# "Dunning, John" <jrd@akamai.com>                        NaN
# "Eduardo A. =?utf-8?b?U3XDoXJleg==?=" <esuarez@...      1.0
# "Eggert, Lars" <lars@netapp.com>                        3.0
# "Fabio Pietrosanti (naif) - lists" <lists@infos...      NaN
# "Fossati, Thomas (Nokia - GB)" <thomas.fossati@...      NaN
# "Fossati, Thomas (Nokia - GB/Cambridge, UK)" <t...      NaN
# "Fred Baker (fred)" <fred@cisco.com>                   10.0
# "Giovane C. M. Moura" <giovane.moura@sidn.nl>           1.0
# "Hannes Tschofenig" <Hannes.Tschofenig@gmx.net>         1.0
# "Hosnieh Rafiee" <ietf@rozanak.com>                     9.0
# "J.C. Jones" <jjones@mozilla.com>                       NaN
# "Jiankang Yao" <yaojk@cnnic.cn>                         2.0
# "Jianqiang Wang" <wanderer.as.me@gmail.com>             NaN
# "Joe Hildebrand (jhildebr)" <jhildebr@cisco.com>        NaN
# "Joe St Sauver" <joe@oregon.uoregon.edu>                7.0
# "John Levine" <johnl@taugh.com>                         5.0
# "John R Levine" <johnl@taugh.com>                       5.0
# "Learmonth, Iain Ross" <iain.learmonth.09@aberd...     12.0
# "Manger, James" <James.H.Manger@team.telstra.com>       NaN
# "Matt Larson via RT" <ietf-action@ietf.org>             1.0
# ...                                                     ...
# Yoav Nir <ynir.ietf@gmail.com>                          NaN
# Yoav Nir <ynir@checkpoint.com>                         22.0
# Zach Shepherd <shepherdz@vmware.com>                    NaN
# Zi Hu <zihu@usc.edu>                                    1.0
# avri <avri@acm.org>                                     1.0
# carlo von lynX <lynX@youfixtheinternet.psyced.org>      2.0
# dan@geer.org                                            7.0
# goblackhole <goblackhole@riseup.net>                    NaN
# hallam@gmail.com                                        NaN
# heinerhummel@aol.com                                    2.0
# home <sxpert@sxpert.org>                                1.0
# housley@vigilsec.com                                    NaN
# ietf <paf@frobbit.se>                                   1.0
# internet-drafts@ietf.org                                NaN
# joel jaeggli <joelja@bogus.com>                        11.0
# karl m <malbrain@yahoo.com>                             1.0
# kathleen.moriarty.ietf@gmail.com                        NaN
# lists@tumbolandia.net (Michele =?utf-8?Q?Orr=C3...      NaN
# lynX@youfixtheinternet.psyced.org                       1.0
# manning bill <bmanning@isi.edu>                        11.0
# moparisthebest <admin@moparisthebest.com>               NaN
# mrex@sap.com (Martin Rex)                               2.0
# ned+perpass@mrochek.com                                20.0
# pindar wong <pindar.wong@gmail.com>                     1.0
# rolf.homburg@dutchpost.net                              NaN
# sanjay.mishra@verizon.com                               NaN
# stephen.farrell@cs.tcd.ie                               1.0
# tytso@mit.edu                                           2.0
# wilton@isoc.org                                         1.0
# yan <yan@eff.org>                                       NaN
#
#                                                                                 email  \
# From
# "Adrian Farrel" <adrian@olddog.co.uk>                             adrian@olddog.co.uk
# "Andreas Kuckartz" <a.kuckartz@ping.de>                            a.kuckartz@ping.de
# "Andy Ligg" <andy@startssl.com>                                                   NaN
# "Bernie Volz (volz)" <volz@cisco.com>                                  volz@cisco.com
# "Carl S. Gutekunst" <cgutekunst@sonicwall.com>               cgutekunst@sonicwall.com
# "Christian Huitema " <huitema@huitema.net>                        huitema@huitema.net
# "Christian Huitema" <huitema@huitema.net>                         huitema@huitema.net
# "Cullen Jennings (fluffy)" <fluffy@cisco.com>                        fluffy@cisco.com
# "Dickson, Brian" <bdickson@verisign.com>                        bdickson@verisign.com
# "Dr. Pala" <director@openca.org>                                                  NaN
# "Dunning, John" <jrd@akamai.com>                                                  NaN
# "Eduardo A. =?utf-8?b?U3XDoXJleg==?=" <esuarez@...  esuarez@fcaglp.fcaglp.unlp.edu.ar
# "Eggert, Lars" <lars@netapp.com>                                      lars@netapp.com
# "Fabio Pietrosanti (naif) - lists" <lists@infos...                                NaN
# "Fossati, Thomas (Nokia - GB)" <thomas.fossati@...                                NaN
# "Fossati, Thomas (Nokia - GB/Cambridge, UK)" <t...                                NaN
# "Fred Baker (fred)" <fred@cisco.com>                                   fred@cisco.com
# "Giovane C. M. Moura" <giovane.moura@sidn.nl>                   giovane.moura@sidn.nl
# "Hannes Tschofenig" <Hannes.Tschofenig@gmx.net>             Hannes.Tschofenig@gmx.net
# "Hosnieh Rafiee" <ietf@rozanak.com>                                  ietf@rozanak.com
# "J.C. Jones" <jjones@mozilla.com>                                                 NaN
# "Jiankang Yao" <yaojk@cnnic.cn>                                        yaojk@cnnic.cn
# "Jianqiang Wang" <wanderer.as.me@gmail.com>                                       NaN
# "Joe Hildebrand (jhildebr)" <jhildebr@cisco.com>                                  NaN
# "Joe St Sauver" <joe@oregon.uoregon.edu>                       joe@oregon.uoregon.edu
# "John Levine" <johnl@taugh.com>                                       johnl@taugh.com
# "John R Levine" <johnl@taugh.com>                                     johnl@taugh.com
# "Learmonth, Iain Ross" <iain.learmonth.09@aberd...   iain.learmonth.09@aberdeen.ac.uk
# "Manger, James" <James.H.Manger@team.telstra.com>                                 NaN
# "Matt Larson via RT" <ietf-action@ietf.org>                      ietf-action@ietf.org
# ...                                                                               ...
# Yoav Nir <ynir.ietf@gmail.com>                                                    NaN
# Yoav Nir <ynir@checkpoint.com>                                    ynir@checkpoint.com
# Zach Shepherd <shepherdz@vmware.com>                                              NaN
# Zi Hu <zihu@usc.edu>                                                     zihu@usc.edu
# avri <avri@acm.org>                                                      avri@acm.org
# carlo von lynX <lynX@youfixtheinternet.psyced.org>  lynX@youfixtheinternet.psyced.org
# dan@geer.org                                                             dan@geer.org
# goblackhole <goblackhole@riseup.net>                                              NaN
# hallam@gmail.com                                                                  NaN
# heinerhummel@aol.com                                             heinerhummel@aol.com
# home <sxpert@sxpert.org>                                            sxpert@sxpert.org
# housley@vigilsec.com                                                              NaN
# ietf <paf@frobbit.se>                                                  paf@frobbit.se
# internet-drafts@ietf.org                                                          NaN
# joel jaeggli <joelja@bogus.com>                                      joelja@bogus.com
# karl m <malbrain@yahoo.com>                                        malbrain@yahoo.com
# kathleen.moriarty.ietf@gmail.com                                                  NaN
# lists@tumbolandia.net (Michele =?utf-8?Q?Orr=C3...                                NaN
# lynX@youfixtheinternet.psyced.org                   lynX@youfixtheinternet.psyced.org
# manning bill <bmanning@isi.edu>                                      bmanning@isi.edu
# moparisthebest <admin@moparisthebest.com>                                         NaN
# mrex@sap.com (Martin Rex)                                                mrex@sap.com
# ned+perpass@mrochek.com                                       ned+perpass@mrochek.com
# pindar wong <pindar.wong@gmail.com>                             pindar.wong@gmail.com
# rolf.homburg@dutchpost.net                                                        NaN
# sanjay.mishra@verizon.com                                                         NaN
# stephen.farrell@cs.tcd.ie                                   stephen.farrell@cs.tcd.ie
# tytso@mit.edu                                                           tytso@mit.edu
# wilton@isoc.org                                                       wilton@isoc.org
# yan <yan@eff.org>                                                                 NaN
#
#                                                                                    name  \
# From
# "Adrian Farrel" <adrian@olddog.co.uk>                                     Adrian Farrel
# "Andreas Kuckartz" <a.kuckartz@ping.de>                                Andreas Kuckartz
# "Andy Ligg" <andy@startssl.com>                                                     NaN
# "Bernie Volz (volz)" <volz@cisco.com>                                Bernie Volz (volz)
# "Carl S. Gutekunst" <cgutekunst@sonicwall.com>                        Carl S. Gutekunst
# "Christian Huitema " <huitema@huitema.net>                           Christian Huitema
# "Christian Huitema" <huitema@huitema.net>                             Christian Huitema
# "Cullen Jennings (fluffy)" <fluffy@cisco.com>                  Cullen Jennings (fluffy)
# "Dickson, Brian" <bdickson@verisign.com>                                 Dickson, Brian
# "Dr. Pala" <director@openca.org>                                                    NaN
# "Dunning, John" <jrd@akamai.com>                                                    NaN
# "Eduardo A. =?utf-8?b?U3XDoXJleg==?=" <esuarez@...  Eduardo A. =?utf-8?b?U3XDoXJleg==?=
# "Eggert, Lars" <lars@netapp.com>                                           Eggert, Lars
# "Fabio Pietrosanti (naif) - lists" <lists@infos...                                  NaN
# "Fossati, Thomas (Nokia - GB)" <thomas.fossati@...                                  NaN
# "Fossati, Thomas (Nokia - GB/Cambridge, UK)" <t...                                  NaN
# "Fred Baker (fred)" <fred@cisco.com>                                  Fred Baker (fred)
# "Giovane C. M. Moura" <giovane.moura@sidn.nl>                       Giovane C. M. Moura
# "Hannes Tschofenig" <Hannes.Tschofenig@gmx.net>                       Hannes Tschofenig
# "Hosnieh Rafiee" <ietf@rozanak.com>                                      Hosnieh Rafiee
# "J.C. Jones" <jjones@mozilla.com>                                                   NaN
# "Jiankang Yao" <yaojk@cnnic.cn>                                            Jiankang Yao
# "Jianqiang Wang" <wanderer.as.me@gmail.com>                                         NaN
# "Joe Hildebrand (jhildebr)" <jhildebr@cisco.com>                                    NaN
# "Joe St Sauver" <joe@oregon.uoregon.edu>                                  Joe St Sauver
# "John Levine" <johnl@taugh.com>                                             John Levine
# "John R Levine" <johnl@taugh.com>                                         John R Levine
# "Learmonth, Iain Ross" <iain.learmonth.09@aberd...                 Learmonth, Iain Ross
# "Manger, James" <James.H.Manger@team.telstra.com>                                   NaN
# "Matt Larson via RT" <ietf-action@ietf.org>                          Matt Larson via RT
# ...                                                                                 ...
# Yoav Nir <ynir.ietf@gmail.com>                                                      NaN
# Yoav Nir <ynir@checkpoint.com>                                                 Yoav Nir
# Zach Shepherd <shepherdz@vmware.com>                                                NaN
# Zi Hu <zihu@usc.edu>                                                              Zi Hu
# avri <avri@acm.org>                                                                avri
# carlo von lynX <lynX@youfixtheinternet.psyced.org>                       carlo von lynX
# dan@geer.org
# goblackhole <goblackhole@riseup.net>                                                NaN
# hallam@gmail.com                                                                    NaN
# heinerhummel@aol.com
# home <sxpert@sxpert.org>                                                           home
# housley@vigilsec.com                                                                NaN
# ietf <paf@frobbit.se>                                                              ietf
# internet-drafts@ietf.org                                                            NaN
# joel jaeggli <joelja@bogus.com>                                            joel jaeggli
# karl m <malbrain@yahoo.com>                                                      karl m
# kathleen.moriarty.ietf@gmail.com                                                    NaN
# lists@tumbolandia.net (Michele =?utf-8?Q?Orr=C3...                                  NaN
# lynX@youfixtheinternet.psyced.org
# manning bill <bmanning@isi.edu>                                            manning bill
# moparisthebest <admin@moparisthebest.com>                                           NaN
# mrex@sap.com (Martin Rex)                                                    Martin Rex
# ned+perpass@mrochek.com
# pindar wong <pindar.wong@gmail.com>                                         pindar wong
# rolf.homburg@dutchpost.net                                                          NaN
# sanjay.mishra@verizon.com                                                           NaN
# stephen.farrell@cs.tcd.ie
# tytso@mit.edu
# wilton@isoc.org
# yan <yan@eff.org>                                                                   NaN
#
#                                                     acme
# From
# "Adrian Farrel" <adrian@olddog.co.uk>                NaN
# "Andreas Kuckartz" <a.kuckartz@ping.de>              NaN
# "Andy Ligg" <andy@startssl.com>                      2.0
# "Bernie Volz (volz)" <volz@cisco.com>                NaN
# "Carl S. Gutekunst" <cgutekunst@sonicwall.com>       NaN
# "Christian Huitema " <huitema@huitema.net>           NaN
# "Christian Huitema" <huitema@huitema.net>            NaN
# "Cullen Jennings (fluffy)" <fluffy@cisco.com>        NaN
# "Dickson, Brian" <bdickson@verisign.com>             NaN
# "Dr. Pala" <director@openca.org>                     3.0
# "Dunning, John" <jrd@akamai.com>                     2.0
# "Eduardo A. =?utf-8?b?U3XDoXJleg==?=" <esuarez@...   NaN
# "Eggert, Lars" <lars@netapp.com>                     NaN
# "Fabio Pietrosanti (naif) - lists" <lists@infos...   2.0
# "Fossati, Thomas (Nokia - GB)" <thomas.fossati@...   1.0
# "Fossati, Thomas (Nokia - GB/Cambridge, UK)" <t...   6.0
# "Fred Baker (fred)" <fred@cisco.com>                 NaN
# "Giovane C. M. Moura" <giovane.moura@sidn.nl>        NaN
# "Hannes Tschofenig" <Hannes.Tschofenig@gmx.net>      NaN
# "Hosnieh Rafiee" <ietf@rozanak.com>                  NaN
# "J.C. Jones" <jjones@mozilla.com>                    8.0
# "Jiankang Yao" <yaojk@cnnic.cn>                      NaN
# "Jianqiang Wang" <wanderer.as.me@gmail.com>          1.0
# "Joe Hildebrand (jhildebr)" <jhildebr@cisco.com>     2.0
# "Joe St Sauver" <joe@oregon.uoregon.edu>             NaN
# "John Levine" <johnl@taugh.com>                      NaN
# "John R Levine" <johnl@taugh.com>                    NaN
# "Learmonth, Iain Ross" <iain.learmonth.09@aberd...   NaN
# "Manger, James" <James.H.Manger@team.telstra.com>    5.0
# "Matt Larson via RT" <ietf-action@ietf.org>          NaN
# ...                                                  ...
# Yoav Nir <ynir.ietf@gmail.com>                      20.0
# Yoav Nir <ynir@checkpoint.com>                       NaN
# Zach Shepherd <shepherdz@vmware.com>                18.0
# Zi Hu <zihu@usc.edu>                                 NaN
# avri <avri@acm.org>                                  NaN
# carlo von lynX <lynX@youfixtheinternet.psyced.org>   NaN
# dan@geer.org                                         NaN
# goblackhole <goblackhole@riseup.net>                 1.0
# hallam@gmail.com                                     2.0
# heinerhummel@aol.com                                 NaN
# home <sxpert@sxpert.org>                             NaN
# housley@vigilsec.com                                 1.0
# ietf <paf@frobbit.se>                                NaN
# internet-drafts@ietf.org                            20.0
# joel jaeggli <joelja@bogus.com>                      NaN
# karl m <malbrain@yahoo.com>                          NaN
# kathleen.moriarty.ietf@gmail.com                     1.0
# lists@tumbolandia.net (Michele =?utf-8?Q?Orr=C3...   1.0
# lynX@youfixtheinternet.psyced.org                    NaN
# manning bill <bmanning@isi.edu>                      NaN
# moparisthebest <admin@moparisthebest.com>            5.0
# mrex@sap.com (Martin Rex)                            NaN
# ned+perpass@mrochek.com                              NaN
# pindar wong <pindar.wong@gmail.com>                  NaN
# rolf.homburg@dutchpost.net                           2.0
# sanjay.mishra@verizon.com                            2.0
# stephen.farrell@cs.tcd.ie                            1.0
# tytso@mit.edu                                        NaN
# wilton@isoc.org                                      NaN
# yan <yan@eff.org>                                    4.0
#
# [420 rows x 4 columns]
